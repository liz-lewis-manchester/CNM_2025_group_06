# %% [markdown]
# <a href="https://colab.research.google.com/github/liz-lewis-manchester/CNM_2025_group_06/blob/equation_function/Declaring_variables.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#we need to declare variables
L = int(input("Enter domain size for length (m)"))
T = int(input("Enter domain size for time (s) ")) #inputs for space and time
Nx = 0
Nt = 0
dx = 0
dt = 0
print("option 1: input Nx and Nt ")
print("option 2: input Δ𝑥 and Δt ")
print("enter 1 for option 1 or enter 2 for option 2")
a = input()
if a == "1":
  Nx = int(input("Enter Nx "))
  Nt = int(input("Enter Nx "))
else:
  dx = int(input("Enter Δ𝑥 "))
  dt = int(input("Enter Δt "))

  Nx = int(L/dx) + 1
  Nt = int(T/dt) + 1 # works out Nt and Nx based on the inputs of dx and dt


print()
print("Length is ", L)
print()
print("Time is ", T)
print()
print("Nx is ", Nx)
print()
print("Nt is ", Nt)
print()
print("Δ𝑥 is ", dx)
print()
print("Δt is ", dt)

oldt = np.zeros(Nx-1)
newt = np.zeros(Nx-1)
A = np.zeros(Nx-2)
B = np.zeros(Nx-2)
F = np.zeros(Nx-2) #initialises all the arrays needed
# Out:
# Enter domain size for length (m)300
# Enter domain size for time (s) 2
# option 1: input Nx and Nt
# option 2: input Δ𝑥 and Δt
# enter 1 for option 1 or enter 2 for option 2
# 2
# Enter Δ𝑥 3
# Enter Δt 3
#
# Length is  300
#
# Time is  2
#
# Nx is  101
#
# Nt is  1
#
# Δ𝑥 is  3
#
# Δt is  3
