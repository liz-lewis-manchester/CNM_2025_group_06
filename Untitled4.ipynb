# %% [markdown]
# <a href="https://colab.research.google.com/github/liz-lewis-manchester/CNM_2025_group_06/blob/equation_function/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#this step aims to take the raw numerical results and extract meaningful information to understand what happened in the simulation.
#find and calculate the mass
mass_initial=np.sum(theta[0,:])*dx
mass_final=np.sum(theta[-1,:])*dx
mass_change=((mass_final-mass_initial)/mass_initial)*100

#find the peak location
mass_initial_concentration=np.max(theta[0,:])
mass_final_concentration=np.max(theta[-1,:])
peak_location=x[np.argmax(theta[-1,:])]
